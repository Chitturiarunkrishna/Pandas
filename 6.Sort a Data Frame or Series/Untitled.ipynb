# %%
import pandas as pd
imd = pd.read_table('imdb.csv', sep=',')
imd.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
imd['title'].sort_values(ascending=False)
# Out:
# 864                                  [Rec]
# 526                                   Zulu
# 615                             Zombieland
# 677                                 Zodiac
# 955                       Zero Dark Thirty
# 535                                  Zelig
# 280                     Young Frankenstein
# 96                                 Yojimbo
# 235                                Yip Man
# 403                             Ying xiong
# 695                      Y Tu Mama Tambien
# 871                                     X2
# 532                     X-Men: First Class
# 248             X-Men: Days of Future Past
# 954                                  X-Men
# 518                         Wreck-It Ralph
# 970                            Wonder Boys
# 65             Witness for the Prosecution
# 920                                Witness
# 483                           Withnail & I
# 270                        Wings of Desire
# 497    Willy Wonka & the Chocolate Factory
# ...

# %%
imd.sort_values('title',ascending=False)
# Out:
#      star_rating                                title content_rating  \
# 864          7.5                                [Rec]              R
# 526          7.8                                 Zulu        UNRATED
# 615          7.7                           Zombieland              R
# 677          7.7                               Zodiac              R
# 955          7.4                     Zero Dark Thirty              R
# 535          7.8                                Zelig             PG
# 280          8.1                   Young Frankenstein             PG
# 96           8.4                              Yojimbo        UNRATED
# 235          8.1                              Yip Man              R
# 403          7.9                           Ying xiong          PG-13
# 695          7.7                    Y Tu Mama Tambien              R
# 871          7.5                                   X2          PG-13
# 532          7.8                   X-Men: First Class          PG-13
# ...

# %%
imd.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
imd.sort_values(['star_rating', 'title'], ascending=False)
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 7            8.9      The Lord of the Rings: The Return of the King
# 6            8.9                     The Good, the Bad and the Ugly
# 8            8.9                                   Schindler's List
# 4            8.9                                       Pulp Fiction
# 9            8.9                                         Fight Club
# 5            8.9                                       12 Angry Men
# 14           8.8              The Lord of the Rings: The Two Towers
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...
